# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
df = pd.DataFrame(data)

# %%
new_df = pd.DataFrame(data, index = ["Fatih", "Tuğçe", "Tito", "Mehmet"], columns = ["Salary", "Age", "Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Fatih   0.480421  0.546631   0.425722
# Tuğçe  -0.806675 -0.242112  -1.221704
# Tito    0.276134 -0.558003   1.138412
# Mehmet -0.689882 -1.269694  -0.606894

# %%
new_df[["Age","Seniority"]]
# Out:
#              Age  Seniority
# Fatih   0.546631   0.425722
# Tuğçe  -0.242112  -1.221704
# Tito   -0.558003   1.138412
# Mehmet -1.269694  -0.606894

# %%
new_df.loc["Fatih"] #indexte isim varsa.
# Out:
# Salary       0.480421
# Age          0.546631
# Seniority    0.425722
# Name: Fatih, dtype: float64

# %%
new_df.iloc[1] #indexte isim varsa.
# Out:
# Salary      -0.806675
# Age         -0.242112
# Seniority   -1.221704
# Name: Tuğçe, dtype: float64

# %%
new_df.iloc[:,0]
# Out:
# Fatih     0.480421
# Tuğçe    -0.806675
# Tito      0.276134
# Mehmet   -0.689882
# Name: Salary, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Fatih   0.480421  0.546631   0.425722     10
# Tuğçe  -0.806675 -0.242112  -1.221704     10
# Tito    0.276134 -0.558003   1.138412     10
# Mehmet -0.689882 -1.269694  -0.606894     10

# %%
new_df.drop("Extra", axis=1) #axis 1 ise kolon, 0 ise row.
# Out:
#           Salary       Age  Seniority
# Fatih   0.480421  0.546631   0.425722
# Tuğçe  -0.806675 -0.242112  -1.221704
# Tito    0.276134 -0.558003   1.138412
# Mehmet -0.689882 -1.269694  -0.606894

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Fatih   0.480421  0.546631   0.425722     10
# Tuğçe  -0.806675 -0.242112  -1.221704     10
# Tito    0.276134 -0.558003   1.138412     10
# Mehmet -0.689882 -1.269694  -0.606894     10

# %%
new_df.drop("Extra", axis=1 , inplace = True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Fatih   0.480421  0.546631   0.425722
# Tuğçe  -0.806675 -0.242112  -1.221704
# Tito    0.276134 -0.558003   1.138412
# Mehmet -0.689882 -1.269694  -0.606894

# %%
new_df.loc["Fatih", "Salary"]
# Out:
# 0.4804206506400387

# %%
new_df.loc["Fatih", "Salary"] = 100

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Fatih   100.000000  0.546631   0.425722
# Tuğçe    -0.806675 -0.242112  -1.221704
# Tito      0.276134 -0.558003   1.138412
# Mehmet   -0.689882 -1.269694  -0.606894

# %%
new_df > 0
# Out:
#         Salary    Age  Seniority
# Fatih     True   True       True
# Tuğçe    False  False      False
# Tito      True  False       True
# Mehmet   False  False      False

# %%
new_df[new_df > 0]
# Out:
#             Salary       Age  Seniority
# Fatih   100.000000  0.546631   0.425722
# Tuğçe          NaN       NaN        NaN
# Tito      0.276134       NaN   1.138412
# Mehmet         NaN       NaN        NaN

# %%
new_df[new_df["Salary"] > 0]
# Out:
#            Salary       Age  Seniority
# Fatih  100.000000  0.546631   0.425722
# Tito     0.276134 -0.558003   1.138412

# %%
branch_df = pd.read_excel("C:/Users/S73792/Desktop/Dosyalar/202412/pivot_test.xlsx")

# %%
branch_df
# Out:
#      ADANA  YENİ ADANA  ADANA BARKAL  CEYHAN  GAZİPAŞA  ÇUKUROVA  ADANA TOROS  \
# 0       10          11            12      13        14        16           17
# 1       20          22            24      26        28        32           34
# 2       30          33            36      39        42        48           51
# 3       64          70            76      82        88       100          106
# 4      132         144           156     168       180       204          216
# 5      268         292           316     340       364       412          436
# 6      540         588           636     684       732       828          876
# 7     1084        1180          1276    1372      1468      1660         1756
# 8     2172        2364          2556    2748      2940      3324         3516
# 9     4348        4732          5116    5500      5884      6652         7036
# 10    8700        9468         10236   11004     11772     13308        14076
# ...

# %%
branch_df.head()
# Out:
#    ADANA  YENİ ADANA  ADANA BARKAL  CEYHAN  GAZİPAŞA  ÇUKUROVA  ADANA TOROS  \
# 0     10          11            12      13        14        16           17
# 1     20          22            24      26        28        32           34
# 2     30          33            36      39        42        48           51
# 3     64          70            76      82        88       100          106
# 4    132         144           156     168       180       204          216
#
#    KOZAN
# 0     18
# 1     36
# 2     54
# 3    112
# 4    228

# %%
branch_df.tail()
# Out:
#      ADANA  YENİ ADANA  ADANA BARKAL  CEYHAN  GAZİPAŞA  ÇUKUROVA  ADANA TOROS  \
# 11   17404       18940         20476   22012     23548     26620        28156
# 12   34812       37884         40956   44028     47100     53244        56316
# 13   69628       75772         81916   88060     94204    106492       112636
# 14  139260      151548        163836  176124    188412    212988       225276
# 15  278524      303100        327676  352252    376828    425980       450556
#
#      KOZAN
# 11   29692
# 12   59388
# 13  118780
# 14  237564
# 15  475132

# %%
branch_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ADANA         16 non-null     int64
#  1   YENİ ADANA    16 non-null     int64
#  2   ADANA BARKAL  16 non-null     int64
#  3   CEYHAN        16 non-null     int64
#  4   GAZİPAŞA      16 non-null     int64
#  5   ÇUKUROVA      16 non-null     int64
#  6   ADANA TOROS   16 non-null     int64
#  7   KOZAN         16 non-null     int64
# dtypes: int64(8)
# memory usage: 1.1 KB

# %%
branch_df.describe()
# Out:
#                ADANA     YENİ ADANA   ADANA BARKAL         CEYHAN  \
# count      16.000000      16.000000      16.000000      16.000000
# mean    34812.250000   37884.250000   40956.250000   44028.250000
# std     74852.027008   81456.628565   88061.230122   94665.831679
# min        10.000000      11.000000      12.000000      13.000000
# 25%       115.000000     125.500000     136.000000     146.500000
# 50%      1628.000000    1772.000000    1916.000000    2060.000000
# 75%     21756.000000   23676.000000   25596.000000   27516.000000
# max    278524.000000  303100.000000  327676.000000  352252.000000
#
#             GAZİPAŞA       ÇUKUROVA    ADANA TOROS          KOZAN
# count      16.000000      16.000000      16.000000      16.000000
# mean    47100.250000   53244.250000   56316.250000   59388.250000
# std    101270.433237  114479.636351  121084.237909  127688.839466
# min        14.000000      16.000000      17.000000      18.000000
# ...

# %%
branch_df_na = pd.read_excel("C:/Users/S73792/Desktop/Dosyalar/202412/pivot_test_na.xlsx")

# %%
# working with na data

# %%
branch_df_na
# Out:
#        ADANA  YENİ ADANA  ADANA BARKAL    CEYHAN  GAZİPAŞA  ÇUKUROVA  \
# 0       10.0        11.0          12.0      13.0      14.0      16.0
# 1       20.0        22.0          24.0      26.0      28.0      32.0
# 2       30.0        33.0          36.0      39.0      42.0      48.0
# 3       64.0        70.0          76.0      82.0      88.0     100.0
# 4      132.0       144.0         156.0     168.0     180.0     204.0
# 5      268.0         NaN           NaN     340.0     364.0     412.0
# 6      540.0       588.0         636.0     684.0     732.0     828.0
# 7     1084.0      1180.0        1276.0    1372.0    1468.0    1660.0
# 8        NaN      2364.0        2556.0       NaN    2940.0    3324.0
# 9     4348.0      4732.0        5116.0    5500.0    5884.0       NaN
# 10    8700.0      9468.0       10236.0   11004.0   11772.0   13308.0
# 11   17404.0         NaN           NaN   22012.0   23548.0   26620.0
# 12       NaN     37884.0       40956.0   44028.0   47100.0   53244.0
# ...

# %%
branch_df_na.isna()
# Out:
#     ADANA  YENİ ADANA  ADANA BARKAL  CEYHAN  GAZİPAŞA  ÇUKUROVA  ADANA TOROS  \
# 0   False       False         False   False     False     False        False
# 1   False       False         False   False     False     False        False
# 2   False       False         False   False     False     False        False
# 3   False       False         False   False     False     False        False
# 4   False       False         False   False     False     False        False
# 5   False        True          True   False     False     False        False
# 6   False       False         False   False     False     False        False
# 7   False       False         False   False     False     False        False
# 8    True       False         False    True     False     False        False
# 9   False       False         False   False     False      True         True
# 10  False       False         False   False     False     False        False
# ...

# %%
branch_df_na["ADANA"]
# Out:
# 0         10.0
# 1         20.0
# 2         30.0
# 3         64.0
# 4        132.0
# 5        268.0
# 6        540.0
# 7       1084.0
# 8          NaN
# 9       4348.0
# 10      8700.0
# 11     17404.0
# 12         NaN
# 13     69628.0
# 14         NaN
# 15    278524.0
# Name: ADANA, dtype: float64

# %%
branch_df_na.dropna()
# Out:
#        ADANA  YENİ ADANA  ADANA BARKAL    CEYHAN  GAZİPAŞA  ÇUKUROVA  \
# 0       10.0        11.0          12.0      13.0      14.0      16.0
# 1       20.0        22.0          24.0      26.0      28.0      32.0
# 2       30.0        33.0          36.0      39.0      42.0      48.0
# 3       64.0        70.0          76.0      82.0      88.0     100.0
# 4      132.0       144.0         156.0     168.0     180.0     204.0
# 6      540.0       588.0         636.0     684.0     732.0     828.0
# 7     1084.0      1180.0        1276.0    1372.0    1468.0    1660.0
# 10    8700.0      9468.0       10236.0   11004.0   11772.0   13308.0
# 15  278524.0    303100.0      327676.0  352252.0  376828.0  425980.0
#
#     ADANA TOROS     KOZAN
# 0          17.0      18.0
# 1          34.0      36.0
# 2          51.0      54.0
# 3         106.0     112.0
# 4         216.0     228.0
# 6         876.0     924.0
# 7        1756.0    1852.0
# 10      14076.0   14844.0
# 15     450556.0  475132.0

# %%
branch_df_na.fillna(0)
# Out:
#        ADANA  YENİ ADANA  ADANA BARKAL    CEYHAN  GAZİPAŞA  ÇUKUROVA  \
# 0       10.0        11.0          12.0      13.0      14.0      16.0
# 1       20.0        22.0          24.0      26.0      28.0      32.0
# 2       30.0        33.0          36.0      39.0      42.0      48.0
# 3       64.0        70.0          76.0      82.0      88.0     100.0
# 4      132.0       144.0         156.0     168.0     180.0     204.0
# 5      268.0         0.0           0.0     340.0     364.0     412.0
# 6      540.0       588.0         636.0     684.0     732.0     828.0
# 7     1084.0      1180.0        1276.0    1372.0    1468.0    1660.0
# 8        0.0      2364.0        2556.0       0.0    2940.0    3324.0
# 9     4348.0      4732.0        5116.0    5500.0    5884.0       0.0
# 10    8700.0      9468.0       10236.0   11004.0   11772.0   13308.0
# 11   17404.0         0.0           0.0   22012.0   23548.0   26620.0
# 12       0.0     37884.0       40956.0   44028.0   47100.0   53244.0
# ...

# %%
# group by

# %%
df = pd.read_excel("C:/Users/S73792/Desktop/Dosyalar/202412/6-employee_df.xlsx")

# %%
df
# Out:
#    Department Employee  Salary  Experience           City
# 0   Marketing    Emp_1   53483           1       New York
# 1       Sales    Emp_2   78555           8         Austin
# 2     Finance    Emp_3   47159           3         Austin
# 3       Sales    Emp_4  110077           3  San Francisco
# 4       Sales    Emp_5   65920           1       New York
# 5          IT    Emp_6   97121          11        Chicago
# 6     Finance    Emp_7   99479           5        Chicago
# 7     Finance    Emp_8  119475          10       New York
# 8     Finance    Emp_9   49457           7        Chicago
# 9       Sales   Emp_10   96557          10        Chicago
# 10  Marketing   Emp_11  107189           9       New York
# 11    Finance   Emp_12  108953          12         Austin
# 12      Sales   Emp_13   82995           7       New York
# 13         IT   Emp_14   70757           9         Austin
# 14  Marketing   Emp_15   39692           8        Chicago
# ...

# %%
df.describe()
# Out:
#               Salary  Experience
# count      50.000000   50.000000
# mean    78344.500000    7.060000
# std     27817.603904    3.966235
# min     31016.000000    1.000000
# 25%     53687.250000    3.000000
# 50%     78769.500000    7.000000
# 75%    100778.000000   10.000000
# max    119812.000000   14.000000

# %%
df[["Salary","Experience"]].mean()
# Out:
# Salary        78344.50
# Experience        7.06
# dtype: float64

# %%
df.head()
# Out:
#   Department Employee  Salary  Experience           City
# 0  Marketing    Emp_1   53483           1       New York
# 1      Sales    Emp_2   78555           8         Austin
# 2    Finance    Emp_3   47159           3         Austin
# 3      Sales    Emp_4  110077           3  San Francisco
# 4      Sales    Emp_5   65920           1       New York

# %%
df_grouped = df.groupby("Department")

# %%
df_grouped.count()
# Out:
#             Employee  Salary  Experience  City
# Department
# Finance           10      10          10    10
# HR                 7       7           7     7
# IT                10      10          10    10
# Marketing         13      13          13    13
# Sales             10      10          10    10

# %%
df_grouped.describe()
# Out:
#            Salary                                                          \
#             count          mean           std      min       25%      50%
# Department
# Finance      10.0  90552.700000  27228.231832  47159.0  73222.00  96591.5
# HR            7.0  76182.571429  31647.523983  31016.0  55114.50  78984.0
# IT           10.0  63381.600000  24272.881041  32568.0  39755.25  66681.5
# Marketing    13.0  79555.000000  28431.207129  39268.0  54300.00  70774.0
# Sales        10.0  81038.900000  26623.181534  38571.0  68987.50  80775.0
#
#                                 Experience                                \
#                   75%       max      count      mean       std  min  25%
# Department
# Finance     111836.75  119812.0       10.0  6.500000  3.566822  1.0  3.5
# HR           96630.00  119789.0        7.0  8.714286  4.572173  3.0  5.0
# IT           79850.00   97121.0       10.0  9.000000  4.163332  1.0  7.5
# ...

# %%
df_city = df.groupby("City")

# %%
df_city[["Experience","Salary"]].mean()
# Out:
#                Experience        Salary
# City
# Austin           6.000000  81216.000000
# Chicago          7.909091  76869.363636
# New York         6.800000  70484.133333
# San Francisco    7.818182  87144.727273

# %%
df1 = pd.read_csv("C:/Users/S73792/Desktop/Dosyalar/202412/7-concat_data1.csv")

# %%
df
# Out:
#    Employee_ID    Name Department
# 0            1   Emp_1    Finance
# 1            2   Emp_2  Marketing
# 2            3   Emp_3         HR
# 3            4   Emp_4    Finance
# 4            5   Emp_5    Finance
# 5            6   Emp_6  Marketing
# 6            7   Emp_7         HR
# 7            8   Emp_8         HR
# 8            9   Emp_9    Finance
# 9           10  Emp_10         IT

# %%
df2 = pd.read_csv("C:/Users/S73792/Desktop/Dosyalar/202412/7-concat_data2.csv")

# %%
df2
# Out:
#    Employee_ID    Name Department
# 0           11  Emp_11    Finance
# 1           12  Emp_12    Finance
# 2           13  Emp_13    Finance
# 3           14  Emp_14    Finance
# 4           15  Emp_15  Marketing
# 5           16  Emp_16         HR
# 6           17  Emp_17  Marketing
# 7           18  Emp_18  Marketing
# 8           19  Emp_19  Marketing
# 9           20  Emp_20    Finance

# %%
df_concat = pd.concat([df1, df2], ignore_index = True)

# %%
df_concat
# Out:
#     Employee_ID    Name Department
# 0             1   Emp_1    Finance
# 1             2   Emp_2  Marketing
# 2             3   Emp_3         HR
# 3             4   Emp_4    Finance
# 4             5   Emp_5    Finance
# 5             6   Emp_6  Marketing
# 6             7   Emp_7         HR
# 7             8   Emp_8         HR
# 8             9   Emp_9    Finance
# 9            10  Emp_10         IT
# 10           11  Emp_11    Finance
# 11           12  Emp_12    Finance
# 12           13  Emp_13    Finance
# 13           14  Emp_14    Finance
# 14           15  Emp_15  Marketing
# 15           16  Emp_16         HR
# 16           17  Emp_17  Marketing
# 17           18  Emp_18  Marketing
# 18           19  Emp_19  Marketing
# 19           20  Emp_20    Finance

# %%
#merge

# %%
df_merge1 = pd.read_csv("C:/Users/S73792/Desktop/Dosyalar/202412/7-merge_data1.csv")

# %%
df_merge1
# Out:
#    Employee_ID    Name Department
# 0            1   Emp_1         IT
# 1            2   Emp_2         HR
# 2            3   Emp_3         IT
# 3            4   Emp_4  Marketing
# 4            5   Emp_5  Marketing
# 5            6   Emp_6         IT
# 6            7   Emp_7         IT
# 7            8   Emp_8         IT
# 8            9   Emp_9  Marketing
# 9           10  Emp_10  Marketing

# %%
df_merge2 = pd.read_csv("C:/Users/S73792/Desktop/Dosyalar/202412/7-merge_data2.csv")

# %%
df_merge2
# Out:
#    Employee_ID  Salary  Experience
# 0            5   55658           3
# 1            1  114478           5
# 2           12   48431          19
# 3           10   32747           7
# 4            6   89150           9
# 5           13   95725           7
# 6            9   65773           4
# 7           11   86886          18

# %%
#merge - outer join

# %%
df_merged_outer = pd.merge(df_merge1, df_merge2, on = "Employee_ID", how="outer")

# %%
df_merged_outer
# Out:
#     Employee_ID    Name Department    Salary  Experience
# 0             1   Emp_1         IT  114478.0         5.0
# 1             2   Emp_2         HR       NaN         NaN
# 2             3   Emp_3         IT       NaN         NaN
# 3             4   Emp_4  Marketing       NaN         NaN
# 4             5   Emp_5  Marketing   55658.0         3.0
# 5             6   Emp_6         IT   89150.0         9.0
# 6             7   Emp_7         IT       NaN         NaN
# 7             8   Emp_8         IT       NaN         NaN
# 8             9   Emp_9  Marketing   65773.0         4.0
# 9            10  Emp_10  Marketing   32747.0         7.0
# 10           12     NaN        NaN   48431.0        19.0
# 11           13     NaN        NaN   95725.0         7.0
# 12           11     NaN        NaN   86886.0        18.0

# %%
# merge - left join

# %%
df_merged_left = pd.merge(df_merge1, df_merge2, on = "Employee_ID", how="left")

# %%
df_merged_left
# Out:
#    Employee_ID    Name Department    Salary  Experience
# 0            1   Emp_1         IT  114478.0         5.0
# 1            2   Emp_2         HR       NaN         NaN
# 2            3   Emp_3         IT       NaN         NaN
# 3            4   Emp_4  Marketing       NaN         NaN
# 4            5   Emp_5  Marketing   55658.0         3.0
# 5            6   Emp_6         IT   89150.0         9.0
# 6            7   Emp_7         IT       NaN         NaN
# 7            8   Emp_8         IT       NaN         NaN
# 8            9   Emp_9  Marketing   65773.0         4.0
# 9           10  Emp_10  Marketing   32747.0         7.0

# %%
# merge - right join

# %%
df_merged_right = pd.merge(df_merge1, df_merge2, on = "Employee_ID", how="right")

# %%
df_merged_right
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0            5   Emp_5  Marketing   55658           3
# 1            1   Emp_1         IT  114478           5
# 2           12     NaN        NaN   48431          19
# 3           10  Emp_10  Marketing   32747           7
# 4            6   Emp_6         IT   89150           9
# 5           13     NaN        NaN   95725           7
# 6            9   Emp_9  Marketing   65773           4
# 7           11     NaN        NaN   86886          18

# %%
# merge - inner join

# %%
df_merged_inner = pd.merge(df_merge1, df_merge2, on = "Employee_ID", how="inner")

# %%
df_merged_inner
# Out:
#    Employee_ID    Name Department  Salary  Experience
# 0            1   Emp_1         IT  114478           5
# 1            5   Emp_5  Marketing   55658           3
# 2            6   Emp_6         IT   89150           9
# 3            9   Emp_9  Marketing   65773           4
# 4           10  Emp_10  Marketing   32747           7

# %%
df = pd.read_csv("C:/Users/S73792/Desktop/Dosyalar/202412/8-apply_function_data.csv")

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
# [100 rows x 6 columns]

# %%
df.describe()
# Out:
#        Employee_ID         Salary  Experience  Performance_Score
# count   100.000000     100.000000  100.000000          100.00000
# mean     50.500000   77508.090000   12.090000            3.03000
# std      29.011492   26083.327596    7.543939            1.41746
# min       1.000000   30206.000000    1.000000            1.00000
# 25%      25.750000   54347.500000    5.000000            2.00000
# 50%      50.500000   80932.000000   12.000000            3.00000
# 75%      75.250000   97620.500000   19.000000            4.00000
# max     100.000000  119474.000000   24.000000            5.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        100 non-null    int64
#  1   Name               100 non-null    object
#  2   Department         100 non-null    object
#  3   Salary             100 non-null    int64
#  4   Experience         100 non-null    int64
#  5   Performance_Score  100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
def salary_category(salary):
    if salary < 5000:
        return "Low"
    elif 5000 <= salary < 8000:
        return "Medium"
    else:
        return "High"

# %%
df["Salary"].apply(salary_category)
# Out:
# 0     High
# 1     High
# 2     High
# 3     High
# 4     High
#       ...
# 95    High
# 96    High
# 97    High
# 98    High
# 99    High
# Name: Salary, Length: 100, dtype: object

# %%
df["Salary_Category"] = df["Salary"].apply(salary_category)

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
#    Salary_Category
# 0             High
# 1             High
# ...

# %%
df["Performance_Score"]
# Out:
# 0     5
# 1     3
# 2     3
# 3     3
# 4     2
#      ..
# 95    4
# 96    2
# 97    3
# 98    1
# 99    3
# Name: Performance_Score, Length: 100, dtype: int64

# %%
# if experience > 10 ise performance_score + 1

# %%
def adjust_new(row):
    if row["Experience"] > 10:
        return row["Performance_Score"] + 1
    else:
        return row["Performance_Score"]

# %%
df
# Out:
#     Employee_ID     Name Department  Salary  Experience  Performance_Score  \
# 0             1    Emp_1  Marketing   82251           6                  5
# 1             2    Emp_2      Sales   52662          24                  3
# 2             3    Emp_3    Finance   38392           5                  3
# 3             4    Emp_4      Sales   60535          20                  3
# 4             5    Emp_5      Sales  108603           2                  2
# ..          ...      ...        ...     ...         ...                ...
# 95           96   Emp_96    Finance   93734          19                  4
# 96           97   Emp_97      Sales  100467          22                  2
# 97           98   Emp_98         IT   82662          23                  3
# 98           99   Emp_99         IT   42688          22                  1
# 99          100  Emp_100         HR   55342          14                  3
#
#    Salary_Category
# 0             High
# 1             High
# ...

# %%
#segmentasyon

# %%
def segmentation(salary):
    if row["Salary"] < 38000:
        return "Mass"
    elif 38001 <= row["Salary"] <= 50000:
        return "High Income"
