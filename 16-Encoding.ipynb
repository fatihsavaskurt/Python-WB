# %% [markdown]
# ### Encoding

# %% [markdown]
# - Machine learning algoritmaları, kategorik değişkenleri algılayamaz. Dolayısıyla kategorik olan değişkenleri numerik olarak belirtmemiz gerekir.
# - Label Encoding -> Düşük, orta, yüksek gibi sıralı verilerde kullanılan encoding biçimidir. Her kategori tek bir sütunda değerlendirilir. Örneğin düşük: 0, orta: 1, yüksek: 2 gibi.
# - One-Hot Encoding -> Mavi, kırmızı, yeşil gibi kategorik verilerde kullanılan encoding biçimidir. Her kategori için ayrı bir sütun oluşturulur. Eğer future bir metin ise kullanılır.

# %% [markdown]
# ### One-Hot Encoding
#
# - Eğer çok fazla kategorik değişken varsa (örneğin 100 farklı renk), 100 tane farklı kolon olacağından dolayı kullanılması mantıklı olmaz.

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Color': ['Red','Blue','Green']
})

# %%
df
# Out:
#    Color
# 0    Red
# 1   Blue
# 2  Green

# %%
df_encoded = pd.get_dummies(df, columns = ['Color'])
print(df_encoded)
# Out:
#    Color_Blue  Color_Green  Color_Red
# 0       False        False       True
# 1        True        False      False
# 2       False         True      False

# %% [markdown]
# ### Label Encoding
#
# - Bir şey devamlı artıyorsa, numerik olarak da artış olacaktır. Örneğin size artıyorsa, numerik de artıyor olacak.

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df['Size_Encoded'] = encoder.fit_transform(df['Size'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Size'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [126], line 5
#       1 from sklearn.preprocessing import LabelEncoder
#       3 encoder = LabelEncoder()
# ----> 5 df['Size_Encoded'] = encoder.fit_transform(df['Size'])
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Size'

# %% [markdown]
# ### Ordinal Encoding
#
# - Burada aslında kategorik değişkene numerik bir sayı verilerel ML algoritması formatına dönüştürme yapılıyor. Örneğin mass segment: 0, QP: 2, AF: 3, AP:4 gibi.

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(segment = [['Mass', 'QP', 'AF', 'AP']])

df["Segment_Level"] = encoder.fit_transform(df['segment'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [127], line 3
#       1 from sklearn.preprocessing import OrdinalEncoder
# ----> 3 encoder = OrdinalEncoder(segment = [['Mass', 'QP', 'AF', 'AP']])
#       5 df["Segment_Level"] = encoder.fit_transform(df['segment'])
#
# TypeError: __init__() got an unexpected keyword argument 'segment'

# %% [markdown]
# ### Frequency Encoding
#
# - Ne kadar sıklıkla görüldüğüne göre, yani frekansına göre numara ataması yapılır.

# %%
df['City_Freq'] = df['City'].map(df['City'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [128], line 1
# ----> 1 df['City_Freq'] = df['City'].map(df['City'].value_counts())
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'City'

# %%
###

# %% [markdown]
# ### Target Encoding
# - Ortalama ile encode edilmesi.

# %%
df['Product_Encoded'] = df.groupby('Product')['Sales'].transform('mean')

# %% [markdown]
# ##### Label Encoding Alıştırma
# - İlk olarak Label Encoder import ediliyor.
# - LabelEncoder fonksiyonu tanımlanıyor.
# - Son olarak fit_transform ile encoding yapılması istenen kolon değiştiriliyor.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df = pd.DataFrame({'Cinsiyet': ['Erkek', 'Kadın', 'Erkek', 'Kadın']})

# %%
le = LabelEncoder()

# %%
df['Cinsiyet_Encoded'] = le.fit_transform(df['Cinsiyet'])

# %%
df
# Out:
#   Cinsiyet  Cinsiyet_Encoded
# 0    Erkek                 0
# 1    Kadın                 1
# 2    Erkek                 0
# 3    Kadın                 1

# %% [markdown]
# ##### Label Encoding Alıştırma
# - İlk olarak Label Encoder import ediliyor.
# - LabelEncoder fonksiyonu tanımlanıyor.
# - Son olarak fit_transform ile encoding yapılması istenen kolon değiştiriliyor.

# %% [markdown]
# ##### One-Hot Alıştırma
# - get_dummies ile, önce istenen df sonrasında da istenen kolon yazılıp encoding yapılıyor.

# %%
df = pd.DataFrame({'Ülke': ['Türkiye', 'Almanya', 'Fransa']})

# %%
df
# Out:
#       Ülke
# 0  Türkiye
# 1  Almanya
# 2   Fransa

# %%
df = pd.get_dummies(df, columns = ['Ülke'])

# %%
df
# Out:
#    Ülke_Almanya  Ülke_Fransa  Ülke_Türkiye
# 0         False        False          True
# 1          True        False         False
# 2         False         True         False

# %% [markdown]
# #### Ordinal Encoding

# %%
categories_list=['Lise', 'Lisans', 'Yüksek Lisans', 'Doktora']

# %%
from sklearn.preprocessing import OrdinalEncoder

df = pd.DataFrame({'Eğitim': ['Lise', 'Lisans', 'Yüksek Lisans', 'Doktora']})
encoder = OrdinalEncoder(categories=[categories_list])
df['Eğitim_encoded'] = encoder.fit_transform(df[['Eğitim']])
print(df)
# Out:
#           Eğitim  Eğitim_encoded
# 0           Lise             0.0
# 1         Lisans             1.0
# 2  Yüksek Lisans             2.0
# 3        Doktora             3.0

# %%
type(categories)
# Out:
# list

# %%
df = pd.DataFrame({
    'Segment': ['Mass', 'QP', 'AF', 'AP', 'P']
})

# %%
segment_list = ['Mass', 'QP', 'AF', 'AP', 'P']

# %%
encoder = OrdinalEncoder(categories = [segment_list])

df['Segment_Encoder'] = encoder.fit_transform(df[['Segment']])
print(df)
# Out:
#   Segment  Segment_Encoder
# 0    Mass              0.0
# 1      QP              1.0
# 2      AF              2.0
# 3      AP              3.0
# 4       P              4.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
df = sns.load_dataset("titanic")

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### Balancing Data (Null değerlerin droplanması veya fill yapılması)

# %%
df['age'].fillna(df['age'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.drop('deck', inplace = True, axis = 1)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
le = LabelEncoder()

# %%
df['class_encoder'] = le.fit_transform(df['class'])

# %%
df.groupby('class')['class_encoder'].unique()
# Out:
# class
# First     [0]
# Second    [1]
# Third     [2]
# Name: class_encoder, dtype: object

# %%
alive_list = [['no', 'yes']]

encoder = OrdinalEncoder(categories=alive_list)
df['alive_f'] = encoder.fit_transform(df[['alive']])

# %%
df.groupby('alive')['alive_f'].unique()
# Out:
# alive
# no     [0.0]
# yes    [1.0]
# Name: alive_f, dtype: object

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone  class_encoder  \
# 0     Third    man        True  Southampton    no  False              2
# 1     First  woman       False    Cherbourg   yes  False              0
# 2     Third  woman       False  Southampton   yes   True              2
# 3     First  woman       False  Southampton   yes  False              0
# 4     Third    man        True  Southampton    no   True              2
# ..      ...    ...         ...          ...   ...    ...            ...
# 886  Second    man        True  Southampton    no   True              1
# 887   First  woman       False  Southampton   yes   True              0
# 888   Third  woman       False  Southampton    no  False              2
# 889   First    man        True    Cherbourg   yes   True              0
# 890   Third    man        True   Queenstown    no   True              2
#
#      alive_f
# 0        0.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        0.0
# ..       ...
# 886      0.0
# 887      1.0
# 888      0.0
# 889      1.0
# 890      0.0
#
# [891 rows x 16 columns]

# %%
df_onehot = pd.get_dummies(df, columns = ['sex', 'embark_town'], drop_first = True)

# %% [markdown]
# - Yukarıdaki kodda, ilk olarak encoding yapılması istenen dataframe seçiliyor. Daha sonrasında, get_dummies metodu kullanılarak encoding yapılacak kolonlar seçiliyor. drop_first ile de aslında ilk kolonları iptal ediyoruz. Örneğin ilgili df'de sex_female kolonu yok, çünkü male true ise male, false ise female olacak şekilde kod kendi kendine ayarladı.

# %%
df_onehot
# Out:
#      survived  pclass        age  sibsp  parch     fare embarked   class  \
# 0           0       3  22.000000      1      0   7.2500        S   Third
# 1           1       1  38.000000      1      0  71.2833        C   First
# 2           1       3  26.000000      0      0   7.9250        S   Third
# 3           1       1  35.000000      1      0  53.1000        S   First
# 4           0       3  35.000000      0      0   8.0500        S   Third
# ..        ...     ...        ...    ...    ...      ...      ...     ...
# 886         0       2  27.000000      0      0  13.0000        S  Second
# 887         1       1  19.000000      0      0  30.0000        S   First
# 888         0       3  29.699118      1      2  23.4500        S   Third
# 889         1       1  26.000000      0      0  30.0000        C   First
# 890         0       3  32.000000      0      0   7.7500        Q   Third
#
#        who  adult_male alive  alone  class_encoder  alive_f  sex_male  \
# 0      man        True    no  False              2      0.0      True
# 1    woman       False   yes  False              0      1.0     False
# 2    woman       False   yes   True              2      1.0     False
# 3    woman       False   yes  False              0      1.0     False
# 4      man        True    no   True              2      0.0      True
# ..     ...         ...   ...    ...            ...      ...       ...
# 886    man        True    no   True              1      0.0      True
# 887  woman       False   yes   True              0      1.0     False
# 888  woman       False    no  False              2      0.0     False
# 889    man        True   yes   True              0      1.0      True
# 890    man        True    no   True              2      0.0      True
#
#      embark_town_Queenstown  embark_town_Southampton
# 0                     False                     True
# 1                     False                    False
# 2                     False                     True
# 3                     False                     True
# 4                     False                     True
# ..                      ...                      ...
# 886                   False                     True
# 887                   False                     True
# 888                   False                     True
# 889                   False                    False
# 890                    True                    False
#
# [891 rows x 17 columns]

# %%
df_onehot.columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'embarked',
#        'class', 'who', 'adult_male', 'alive', 'alone', 'class_encoder',
#        'alive_f', 'sex_male', 'embark_town_Queenstown',
#        'embark_town_Southampton'],
#       dtype='object')
